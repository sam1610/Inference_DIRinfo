# %% [markdown]
# [seaborn.jointplot](http://alanpryorjr.com/visualizations/seaborn/jointplot/jointplot/)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['font.family'] = "serif"

# %%
# Generate some random multivariate data
x, y = np.random.RandomState(8).multivariate_normal([0, 0], [(1, 0), (0, 1)], 1000).T
df = pd.DataFrame({"x":x,"y":y})

# %%
p = sns.jointplot(x='x', y='y', data=df)

# %%
p = sns.jointplot(data=df,x='x', y='y', kind="scatter")

# %%
p = sns.jointplot(data=df,x='x', y='y', kind="reg")

# %%
x2, y2 = np.random.RandomState(9).multivariate_normal([0, 0], [(1, 0), (0, 1)], len(x)).T
df2 = pd.DataFrame({"x":x,"y":y2})

p = sns.jointplot(data=df,x='x', y='y',kind='resid')

# %%
p = sns.jointplot(data=df,x='x', y='y',kind='kde')

# %%
p = sns.jointplot(data=df,x='x', y='y',kind='hex')

# %%
from scipy.stats import tmin
p = sns.jointplot(data=df, x='x', y='y',kind='kde',stat_func=tmin)

# tmin is computing roughly the equivalent of the following
print(df.loc[df.x>df.y,'x'].min())
# Out:
# -1.3726590098674956

# %%
p = sns.jointplot(data=df,
                  x='x',
                  y='y',
                  kind='kde',
                  color="#99ffff")

# %%
p = sns.jointplot(data=df,
                  x='x',
                  y='y',
                  kind='kde',
                  ratio=1)

# %%
from scipy import stats
p = sns.jointplot(data=df,
                  x='x',
                  y='y',
                  kind='kde',
                  space=2)

rsquare = lambda a, b: stats.pearsonr(a, b)[0] ** 2
p = p.annotate(rsquare, template="{stat}: {val:.2f}",
               stat="$R^2$", loc="upper left", fontsize=12)

# %%
p = sns.jointplot(data=df,
                  x='x',
                  y='y',
                  kind='kde',
                  xlim=(-1,1),
                  ylim=(-1,1))

# %%
p = sns.jointplot(data=df,
                  x='x',
                  y='y',
                  kind='kde',
                  marginal_kws={'lw':5,
                                'color':'red'})
p = p.annotate(stats.pearsonr)

# %%
sns.set(rc={'axes.labelsize':30,
            'figure.figsize':(20.0, 10.0),
            'xtick.labelsize':25,
            'ytick.labelsize':20})

from itertools import chain
p = sns.jointplot(data=df,
                  x='x',
                  y='y',
                  kind='kde',
                  xlim=(-3,3),
                  ylim=(-3,3),
                  space=0,
                  stat_func=None,
                  marginal_kws={'lw':3,
                                'bw':0.2}).set_axis_labels('X','Y')
p.ax_marg_x.set_facecolor('#ccffccaa')
p.ax_marg_y.set_facecolor('#ccffccaa')
for l in chain(p.ax_marg_x.axes.lines,p.ax_marg_y.axes.lines):
    l.set_linestyle('--')
    l.set_color('black')
plt.text(-1.7,-2.7, "Joint Plot", fontsize = 55, color='Black', fontstyle='italic')
# Out:
# Text(-1.7, -2.7, 'Joint Plot')

# %%
p.savefig('jointplot.png')

# %%
import pandas as pd
import seaborn as sb
import warnings
from matplotlib import pyplot as plt
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
print(sb.get_dataset_names())
# Out:
# ['anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'iris', 'mpg', 'planets', 'tips', 'titanic']

# %%
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'],hist=False)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.size'] = "30"
sb.distplot(df['petal_length'], bins=50)
plt.show()

# %%
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.size'] = "20"
plt.rcParams['figure.figsize'] = (5,5)
sb.jointplot('petal_length','petal_width',data = df, kind="scatter")
plt.show()

# %%
sb.jointplot(x = 'petal_length',y = 'petal_width',data = df,kind = 'hex')
plt.rcParams['font.family'] = "serif"
plt.rcParams['figure.figsize'] = (20.0, 50.0)
plt.show()

# %%
sb.jointplot(x = 'petal_length',y = 'petal_width',data = df,kind = 'reg', marginal_kws=dict(bins=15, \
                rug=True),annot_kws=dict(stat="r"),s=40, edgecolor="w", linewidth=1)

# %%
sb.jointplot(x = 'petal_length',y = 'petal_width',data = df,kind = 'kde', space=0, color="g")

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
ax = sns.scatterplot(x="total_bill", y="tip", hue="time",
data=tips)

# %%
ax = sns.scatterplot(x="total_bill", y="tip",
hue="time", style="time", data=tips)

# %%
ax = sns.scatterplot(x="total_bill", y="tip",
hue="day", style="time", data=tips)

# %%
ax = sns.scatterplot(x="total_bill", y="tip", size="size",
data=tips)

# %%
ax = sns.scatterplot(x="total_bill", y="tip",
hue="size", size="size",
 data=tips)

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
ax = sns.scatterplot(x="total_bill", y="tip",
hue="size", size="size",
palette=cmap,
data=tips)

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
ax = sns.scatterplot(x="total_bill", y="tip",
hue="size", size="size",
sizes=(20, 200), palette=cmap,
legend="full", data=tips)

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
ax = sns.scatterplot(x="total_bill", y="tip",
hue="day", size="smoker",
palette="Set2",
data=tips)

# %%
markers = {"Lunch": "s", "Dinner": "X"}
ax = sns.scatterplot(x="total_bill", y="tip", style="time",
markers=markers,
data=tips)

# %%
ax = sns.scatterplot(x="total_bill", y="tip",
s=100, color=".2", marker="+",
data=tips)

# %%
iris = sns.load_dataset("iris")
ax = sns.scatterplot(x=iris.sepal_length, y=iris.sepal_width,
hue=iris.species, style=iris.species)

# %%
import numpy as np, pandas as pd; plt.close("all")
index = pd.date_range("1 1 2000", periods=100,
freq="m", name="date")
data = np.random.randn(100, 4).cumsum(axis=0)
wide_df = pd.DataFrame(data, index, ["a", "b", "c", "d"])
ax = sns.scatterplot(data=wide_df)

# %%
g = (sns.jointplot("sepal_length", "sepal_width",
           data=iris, color="k")
.plot_joint(sns.kdeplot, zorder=0, n_levels=6))

# %% [markdown]
# # Analyze the data through data visualization using Seaborn

# %%
tips = sns.load_dataset("tips")
tips.head()

# %%
tips.describe()

# %%
sns.distplot(tips['tip'], kde=False, bins=10);

# %%
sns.distplot(tips['tip'],hist=False, bins=10);

# %%
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", kind="line", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", sort=False, kind="line", data=tips)

# %%
sns.catplot(x="sex", y="tip", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips);

# %%
sns.catplot(x="smoker", y="tip", order=["No", "Yes"], data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="box", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", data=tips);

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="point", data=tips);

# %%
# import the relevant packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# these lines of code render reasonably-sized plots
# within a Jupyter Notebook window:
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
# For presentation, you can turn off warnings
# if they're not an issue for your implementation
import warnings
warnings.filterwarnings('ignore')

# %%
stats.keys()

# %%
stats = pd.read_csv('https://bit.ly/3ajk6ig', names=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup'], header=0)
stats.head()

# %% [markdown]
# # Histogram with Regression

# %%
vis1 = sns.distplot(stats["InternetUsers"], bins=20)

# %%
vis2 = sns.boxplot(data=stats, x='IncomeGroup', y='BirthRate')

# %% [markdown]
# # Scatter Plot

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate',
       fit_reg=False, hue='IncomeGroup', scatter_kws={'s':200})

# %%
movies = pd.read_csv("data/movie_ratings.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d5e70400fd9f> in <module>
# ----> 1 movies = pd.read_csv("data/movie_ratings.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
mpl.rcParams["axes.labelsize"] = 20

my_plot = sns.PairGrid(df)
my_plot = my_plot.map_diag(sns.kdeplot, shade=True)
my_plot = my_plot.map_lower(sns.regplot, scatter_kws={'alpha':0.3})
my_plot.hue_vals = df["species"]
my_plot.hue_names = df["species"].unique()
my_plot.palette = sns.color_palette("Set2", len(my_plot.hue_names))
my_plot = my_plot.map_upper(sns.scatterplot).add_legend(title='Species', fontsize= '12')
